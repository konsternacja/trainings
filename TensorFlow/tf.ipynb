# %%
import tensorflow.compat.v2.feature_column as fc
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
# Out:
# 2023-03-23 22:07:02.354531: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
print(tf.__version__)
# Out:
# 2.11.0

# %%
df = pd.read_csv('ObesityDataSet_raw_and_data_sinthetic.csv')
df.head(10)
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
# 5    Male  29.0    1.62    53.0                             no  yes   2.0
# 6  Female  23.0    1.50    55.0                            yes  yes   3.0
# 7    Male  22.0    1.64    53.0                             no   no   2.0
# 8    Male  24.0    1.78    64.0                            yes  yes   3.0
# 9    Male  22.0    1.72    68.0                            yes  yes   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
# 5  3.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
# 6  3.0  Sometimes    no   2.0   no  1.0  0.0   Sometimes
# 7  3.0  Sometimes    no   2.0   no  3.0  0.0   Sometimes
# 8  3.0  Sometimes    no   2.0   no  1.0  1.0  Frequently
# 9  3.0  Sometimes    no   2.0   no  1.0  1.0          no
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# 2  Public_Transportation        Normal_Weight
# 3                Walking   Overweight_Level_I
# 4  Public_Transportation  Overweight_Level_II
# 5             Automobile        Normal_Weight
# 6              Motorbike        Normal_Weight
# 7  Public_Transportation        Normal_Weight
# 8  Public_Transportation        Normal_Weight
# 9  Public_Transportation        Normal_Weight

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
#  12  FAF                             2111 non-null   float64
#  13  TUE                             2111 non-null   float64
#  14  CALC                            2111 non-null   object
#  15  MTRANS                          2111 non-null   object
#  16  NObeyesdad                      2111 non-null   object
# dtypes: float64(8), object(9)
# memory usage: 280.5+ KB

# %%
df.isnull().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
df['NObeyesdad'].unique()
# Out:
# array(['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II',
#        'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II',
#        'Obesity_Type_III'], dtype=object)

# %%
df.NObeyesdad.hist(bins=7)
# Out:
# <Axes: >

# %%
CATEGORICAL_COLUMNS = ['Gender', 'family_history_with_overweight', 'CAEC', 'SMOKE', 'SCC',
                       'CALC', 'MTRANS','NObeyesdad']
NUMERIC_COLUMNS = ['Age', 'Height','Weight', 'FAVC', 'FCVC','NCP','CH2O','FAF','TUE']

feature_column = []
for feature_name in CATEGORICAL_COLUMNS:
  vocabulary = df[feature_name].unique()  # gets a list of all unique values from given feature column
  feature_column.append(tf.feature_column.categorical_column_with_vocabulary_list(feature_name, vocabulary))

for feature_name in NUMERIC_COLUMNS:
  feature_column.append(tf.feature_column.numeric_column(feature_name, dtype=tf.float32))

print(feature_column)
# Out:
# [VocabularyListCategoricalColumn(key='Gender', vocabulary_list=('Female', 'Male'), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='family_history_with_overweight', vocabulary_list=('yes', 'no'), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='CAEC', vocabulary_list=('Sometimes', 'Frequently', 'Always', 'no'), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='SMOKE', vocabulary_list=('no', 'yes'), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='SCC', vocabulary_list=('no', 'yes'), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='CALC', vocabulary_list=('no', 'Sometimes', 'Frequently', 'Always'), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='MTRANS', vocabulary_list=('Public_Transportation', 'Walking', 'Automobile', 'Motorbike', 'Bike'), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='NObeyesdad', vocabulary_list=('Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II', 'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II', 'Obesity_Type_III'), dtype=tf.string, default_value=-1, num_oov_buckets=0), NumericColumn(key='Age', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='Height', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='Weight', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='FAVC', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='FCVC', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='NCP', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='CH2O', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='FAF', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='TUE', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %%
df.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# 2  Public_Transportation        Normal_Weight
# 3                Walking   Overweight_Level_I
# 4  Public_Transportation  Overweight_Level_II

# %%
x = df
y = x.pop('NObeyesdad')

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.8)

# %%
def make_input_fn(data_df, label_df, num_epochs=10, shuffle=True, batch_size=32):
  def input_function():  # inner function, this will be returned
    ds = tf.data.Dataset.from_tensor_slices((dict(data_df), label_df) ) # create tf.data.Dataset object with data and its label
    if shuffle:
      ds = ds.shuffle(1000)  # randomize order of data
    ds = ds.batch(batch_size).repeat(num_epochs)  # split dataset into batches of 32 and repeat process for number of epochs
    return ds  # return a batch of the dataset
  return input_function  # return a function object for use

train_input_fn = make_input_fn(x_train, y_train)  # here we will call the input_function that was returned to us to get a dataset object we can feed to the model
eval_input_fn = make_input_fn(x_test, y_test, num_epochs=1, shuffle=False)

# %%
linear_est = tf.estimator.LinearClassifier(feature_columns=feature_column)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpoz8r639v
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpoz8r639v', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
linear_est.train(train_input_fn)  # train
result = linear_est.evaluate(eval_input_fn)  # get model metrics/stats by testing on tetsing data

clear_output()  # clears consoke output
print(result['accuracy'])  # the result variable is simply a dict of stats about our model
# Out:
# WARNING:tensorflow:From /home/konsternacja/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow/python/training/training_util.py:396: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Calling model_fn.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 linear_est.train(train_input_fn)  # train
#       2 result = linear_est.evaluate(eval_input_fn)  # get model metrics/stats by testing on tetsing data
#       4 clear_output()  # clears consoke output
#
# File ~/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow_estimator/python/estimator/estimator.py:360, in Estimator.train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     357 hooks.extend(self._convert_train_steps_to_hooks(steps, max_steps))
#     359 saving_listeners = _check_listeners_type(saving_listeners)
# --> 360 loss = self._train_model(input_fn, hooks, saving_listeners)
#     361 logging.info('Loss for final step: %s.', loss)
#     362 return self
#
# File ~/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow_estimator/python/estimator/estimator.py:1186, in Estimator._train_model(self, input_fn, hooks, saving_listeners)
#    1184   return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1185 else:
# -> 1186   return self._train_model_default(input_fn, hooks, saving_listeners)
#
# File ~/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow_estimator/python/estimator/estimator.py:1214, in Estimator._train_model_default(self, input_fn, hooks, saving_listeners)
#    1211 features, labels, input_hooks = (
#    1212     self._get_features_and_labels_from_input_fn(input_fn, ModeKeys.TRAIN))
#    1213 worker_hooks.extend(input_hooks)
# -> 1214 estimator_spec = self._call_model_fn(features, labels, ModeKeys.TRAIN,
#    1215                                      self.config)
#    1216 global_step_tensor = tf.compat.v1.train.get_global_step(g)
#    1217 return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#    1218                                        hooks, global_step_tensor,
#    1219                                        saving_listeners)
#
# File ~/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow_estimator/python/estimator/estimator.py:1174, in Estimator._call_model_fn(self, features, labels, mode, config)
#    1171   kwargs['config'] = config
#    1173 logging.info('Calling model_fn.')
# -> 1174 model_fn_results = self._model_fn(features=features, **kwargs)
#    1175 logging.info('Done calling model_fn.')
#    1177 if not isinstance(model_fn_results, model_fn_lib.EstimatorSpec):
#
# File ~/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow_estimator/python/estimator/canned/linear.py:934, in LinearClassifierV2.__init__.<locals>._model_fn(features, labels, mode, config)
#     932 def _model_fn(features, labels, mode, config):
#     933   """Call the defined shared _linear_model_fn."""
# --> 934   return _linear_model_fn_v2(
#     935       features=features,
#     936       labels=labels,
#     937       mode=mode,
#     938       head=head,
#     939       feature_columns=tuple(feature_columns or []),
#     940       optimizer=optimizer,
#     941       config=config,
#     942       sparse_combiner=sparse_combiner)
#
# File ~/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow_estimator/python/estimator/canned/linear.py:662, in _linear_model_fn_v2(***failed resolving arguments***)
#     659   return _sdca_model_fn(features, labels, mode, head, feature_columns,
#     660                         optimizer)
#     661 else:
# --> 662   logits, trainable_variables = _linear_model_fn_builder_v2(
#     663       units=head.logits_dimension,
#     664       feature_columns=feature_columns,
#     665       sparse_combiner=sparse_combiner,
#     666       features=features)
#     668   # In TRAIN mode, create optimizer and assign global_step variable to
#     669   # optimizer.iterations to make global_step increased correctly, as Hooks
#     670   # relies on global step as step counter.
#     671   if mode == ModeKeys.TRAIN:
#
# File ~/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow_estimator/python/estimator/canned/linear.py:599, in _linear_model_fn_builder_v2(units, feature_columns, sparse_combiner, features)
#     591 # Name scope has no effect on variables in LinearModel, as it uses
#     592 # tf.get_variables() for variable creation. So we modify the model name to
#     593 # keep the variable names the same for checkpoint backward compatibility.
#     594 linear_model = LinearModel(
#     595     feature_columns=feature_columns,
#     596     units=units,
#     597     sparse_combiner=sparse_combiner,
#     598     name='linear/linear_model')
# --> 599 logits = linear_model(features)
#     600 bias = linear_model.bias
#     602 # We'd like to get all the non-bias variables associated with this
#     603 # LinearModel.
#     604 # TODO(rohanj): Figure out how to get shared embedding weights variable
#     605 # here.
#
# File ~/anaconda3/envs/tensorflow/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /tmp/__autograph_generated_filevjwtzjz7.py:28, in outer_factory.<locals>.inner_factory.<locals>.tf__call(self, features)
#      26 try:
#      27     do_return = True
# ---> 28     retval_ = ag__.converted_call(ag__.ld(self).layer, (ag__.ld(features),), None, fscope)
#      29 except:
#      30     do_return = False
#
# File /tmp/__autograph_generated_file5ex9v07c.py:43, in outer_factory.<locals>.inner_factory.<locals>.tf__call(self, features)
#      41 weight_var = ag__.Undefined('weight_var')
#      42 column = ag__.Undefined('column')
# ---> 43 ag__.for_stmt(ag__.ld(self)._feature_columns, None, loop_body, get_state_1, set_state_1, (), {'iterate_names': 'column'})
#      44 ag__.converted_call(ag__.ld(fc_v2)._verify_static_batch_size_equality, (ag__.ld(weighted_sums), ag__.ld(self)._feature_columns), None, fscope)
#      45 predictions_no_bias = ag__.converted_call(ag__.ld(tf).math.add_n, (ag__.ld(weighted_sums),), dict(name='weighted_sum_no_bias'), fscope)
#
# File /tmp/__autograph_generated_file5ex9v07c.py:38, in outer_factory.<locals>.inner_factory.<locals>.tf__call.<locals>.loop_body(itr)
#      36 with ag__.ld(ops).name_scope(ag__.ld(fc_v2)._sanitize_column_name_for_variable_scope(ag__.ld(column).name)):
#      37     weight_var = ag__.converted_call(ag__.ld(self)._state_manager.get_variable, (ag__.ld(column), 'weights'), None, fscope)
# ---> 38     weighted_sum = ag__.converted_call(ag__.ld(fc_v2)._create_weighted_sum, (), dict(column=ag__.ld(column), transformation_cache=ag__.ld(transformation_cache), state_manager=ag__.ld(self)._state_manager, sparse_combiner=ag__.ld(self)._sparse_combiner, weight_var=ag__.ld(weight_var)), fscope)
#      39     ag__.converted_call(ag__.ld(weighted_sums).append, (ag__.ld(weighted_sum),), None, fscope)
#
# ValueError: in user code:
#
#     File "/home/konsternacja/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow_estimator/python/estimator/canned/linear.py", line 1668, in call  *
#         return self.layer(features)
#     File "/home/konsternacja/anaconda3/envs/tensorflow/lib/python3.10/site-packages/tensorflow_estimator/python/estimator/canned/linear.py", line 1496, in call  *
#         weighted_sum = fc_v2._create_weighted_sum(  # pylint: disable=protected-access
#
#     ValueError: Feature NObeyesdad is not in features dictionary.
